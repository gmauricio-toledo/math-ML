# %% [markdown]
# <a href="https://colab.research.google.com/github/gmauricio-toledo/math-ML/blob/main/Tareas/Tarea-04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🔴 Tarea 4: Reducción de dimensionalidad

# %%
import pandas as pd

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
df = pd.read_csv(url, sep=';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
corr_matrix = df.corr().abs()

# Visualizar la matriz de correlación
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlación Absoluta')
plt.show()

# %% [markdown]
# El problema de este dataset consiste en predecir la calidad del vino en función de las variables químicas. Realiza los siguientes pasos:
#
# 1. Separa el conjunto de datos en variables de entrada y salida. Las variables de entrada quedarán en un dataframe, las de salida en un arreglo de numpy.
#
# 2. Inspecciona si hay variables faltantes
#
# 3. Realiza el re-escalamiento que consideres apropiado.
#
# 4. Aquí la actividad se divide en 3 procesos paralelos:
#
#     (a) Selecciona variables inspeccionando las correlaciones y eliminando variables que consideres que inducen multicolinealidad
#
#     (b) Selecciona usando `SelectKBest` usando las etiquetas de los datos `y`. Elige $K$ de forma que coincida con la estrategia (a).
#
#     (c) Haz un análisis de varianza acumulada por componentes principales usando PCA para hacer reducción de dimensionalidad apropiada.
#
# 5. En los casos 4a, 4b y 4c, guarda los datos de entrada $X$ en formato csv.
#
# 6. En el caso 4c, gráfica los datos usando `scatter` haciendo PCA a 2 dimensiones, colorea los puntos por su clase.
